# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Data\Dataset.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\gwm93\AppData\Local\Temp\ipykernel_6592\3504470205.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv("Data\Dataset.csv")
# C:\Users\gwm93\AppData\Local\Temp\ipykernel_6592\3504470205.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv("Data\Dataset.csv")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df=pd.read_csv("Data\Dataset.csv")
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.drop("Restaurant ID",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       9551 non-null   object
#  1   Country Code          9551 non-null   int64
#  2   City                  9551 non-null   object
#  3   Address               9551 non-null   object
#  4   Locality              9551 non-null   object
#  5   Locality Verbose      9551 non-null   object
#  6   Longitude             9551 non-null   float64
#  7   Latitude              9551 non-null   float64
#  8   Cuisines              9542 non-null   object
#  9   Average Cost for two  9551 non-null   int64
#  10  Currency              9551 non-null   object
#  11  Has Table booking     9551 non-null   object
#  12  Has Online delivery   9551 non-null   object
#  13  Is delivering now     9551 non-null   object
#  14  Switch to order menu  9551 non-null   object
# ...

# %%
for i in df.columns:
    print(i,"---",df[i].nunique())
# Out:
# Restaurant Name --- 7446
# Country Code --- 15
# City --- 141
# Address --- 8918
# Locality --- 1208
# Locality Verbose --- 1265
# Longitude --- 8120
# Latitude --- 8677
# Cuisines --- 1825
# Average Cost for two --- 140
# Currency --- 12
# Has Table booking --- 2
# Has Online delivery --- 2
# Is delivering now --- 2
# Switch to order menu --- 1
# Price range --- 4
# Aggregate rating --- 33
# Rating color --- 6
# Rating text --- 6
# Votes --- 1012

# %%
df["Country Code"]=df["Country Code"].astype("object")

# %%
df["Aggregate rating"]
# Out:
# 0       4.8
# 1       4.5
# 2       4.4
# 3       4.9
# 4       4.8
#        ...
# 9546    4.1
# 9547    4.2
# 9548    3.7
# 9549    4.0
# 9550    4.0
# Name: Aggregate rating, Length: 9551, dtype: float64

# %%
numerical_features=[features for features in df.columns if df[features].dtype!="object"]
categorical_features=[features for features in df.columns if df[features].dtype=="object"]

# %%
len(numerical_features)
# Out:
# 6

# %%
numerical_features
# Out:
# ['Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %%
categorical_features
# Out:
# ['Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Rating color',
#  'Rating text']

# %%
categorical_features_label_encoder=[features for features in categorical_features if df[features].nunique()>7]
categorical_features_onehot_encoder=[features for features in categorical_features if features not in categorical_features_label_encoder]

# %%
categorical_features_label_encoder
# Out:
# ['Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Cuisines',
#  'Currency']

# %%
for i in categorical_features_label_encoder:
    print(df[i].nunique())
# Out:
# 7446
# 15
# 141
# 8918
# 1208
# 1265
# 1825
# 12

# %%
numerical_features
# Out:
# ['Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %%
plt.boxplot(df["Price range"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b6923f68d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b6923f6e70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b6923f6690>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b6923f7350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b6923f75f0>],
#  'means': []}

# %%
plt.boxplot(df["Average Cost for two"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b68d597500>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b6923e0530>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b6923cff50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b6923e0110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b6923e0d40>],
#  'means': []}

# %%
x=df.drop("Aggregate rating",axis=1)
y=df["Aggregate rating"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder,LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.svm import SVR 
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
#x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
oh_encoder=OneHotEncoder(drop="first")
label_encoder=LabelEncoder()
standard=StandardScaler()

# %%
x
# Out:
#                Restaurant Name Country Code              City  \
# 0             Le Petit Souffle          162       Makati City
# 1             Izakaya Kikufuji          162       Makati City
# 2       Heat - Edsa Shangri-La          162  Mandaluyong City
# 3                         Ooma          162  Mandaluyong City
# 4                  Sambo Kojin          162  Mandaluyong City
# ...                        ...          ...               ...
# 9546               Naml۱ Gurme          208         ��stanbul
# 9547              Ceviz A��ac۱          208         ��stanbul
# 9548                     Huqqa          208         ��stanbul
# 9549               A���k Kahve          208         ��stanbul
# 9550  Walter's Coffee Roastery          208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# ...

# %%
numerical_features.remove("Aggregate rating")

# %%
numerical_features
# Out:
# ['Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Votes']

# %%
for i in categorical_features_label_encoder:
    x[i]=label_encoder.fit_transform(x[i])

# %%
preprocessor=ColumnTransformer(
    [("oh_encode",oh_encoder,categorical_features_onehot_encoder),
     
     ("standard",standard,numerical_features)
     ],remainder='passthrough'
)

# %%
x=preprocessor.fit_transform(x)

# %%
x
# Out:
# array([[1.000e+00, 0.000e+00, 0.000e+00, ..., 1.720e+02, 9.200e+02,
#         0.000e+00],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 6.010e+02, 1.111e+03,
#         0.000e+00],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 3.140e+02, 1.671e+03,
#         0.000e+00],
#        ...,
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 5.610e+02, 1.110e+03,
#         1.100e+01],
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 5.610e+02, 1.657e+03,
#         1.100e+01],
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 6.810e+02, 3.310e+02,
#         1.100e+01]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "Adaboost Regressor":AdaBoostRegressor(),
    "Graident BoostRegressor":GradientBoostingRegressor(),
    "Xgboost Regressor":XGBRegressor()
   
}

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    
    model.fit(x_train,y_train)
    
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)
    
    
    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    
    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    
    print('='*35)
    print('\n')
# Out:
# Linear Regression
# Model performance for Training set
# - Root Mean Squared Error: 0.1770
# - Mean Absolute Error: 0.1287
# - R2 Score: 0.9864
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.1762
# - Mean Absolute Error: 0.1297
# - R2 Score: 0.9864
# ...
#
#
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 1.4655
# - Mean Absolute Error: 1.1813
# - R2 Score: 0.0682
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 1.4494
# - Mean Absolute Error: 1.1701
# - R2 Score: 0.0771
# ...
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 0.1770
# - Mean Absolute Error: 0.1286
# - R2 Score: 0.9864
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.1762
# - Mean Absolute Error: 0.1295
# - R2 Score: 0.9864
# ...
#
#
# K-Neighbors Regressor
# Model performance for Training set
# - Root Mean Squared Error: 1.2576
# ...

# %%
rf_params = {"max_depth": [5, 8, 15, None, 10],
             "max_features": [5, 7, "auto", 8],
             "min_samples_split": [2, 8, 15, 20],
             "n_estimators": [100, 200, 500, 1000]}

# %%
randomcv_models = [
                   ("RF", RandomForestRegressor(), rf_params),
                   
                   
                   ]

# %%
##Hyperparameter Tuning
from sklearn.model_selection import RandomizedSearchCV

model_param = {}
for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=10,
                                   cv=3,
                                   verbose=2,
                                   n_jobs=-1)
    random.fit(x_train, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# c:\Users\gwm93\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 6 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\gwm93\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\gwm93\anaconda3\Lib\site-packages\sklearn\base.py", line 1356, in wrapper
#     estimator._validate_params()
#   File "c:\Users\gwm93\anaconda3\Lib\site-packages\sklearn\base.py", line 469, in _validate_params
# ...

# %%
import joblib

# %%
## Retraining the models with best parameters
models = {
    "Random Forest Regressor": RandomForestRegressor(n_estimators=100, min_samples_split=2, max_features=5, max_depth=15, 
                                                     n_jobs=-1),
     
    
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)
    
    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    
    print('='*35)
    print('\n')
    joblib.dump(model,"model.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[121], line 7
#       3 from sklearn.ensemble import RandomForestRegressor
#       5 # --------- 1. keep / decide the feature names BEFORE any array conversion ----------
#       6 # If you still have the original DataFrame handy, capture the columns *now*:
# ----> 7 original_feature_names = X.columns.to_list()          # X is your full feature DataFrame
#       8 # -----------------------------------------------------------------------------
#       9
#      10 # --------- 2. define (or re‑define) the model dictionary ----------------------
#      11 models = {
#      12     "Random Forest Regressor":
#      13         RandomForestRegressor(
#    (...)
#      20         ),
#      21 }
#
# NameError: name 'X' is not defined

# %%
x_train
# Out:
# array([[1.000e+00, 0.000e+00, 0.000e+00, ..., 1.199e+03, 1.406e+03,
#         4.000e+00],
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 1.181e+03, 8.280e+02,
#         4.000e+00],
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 9.120e+02, 1.262e+03,
#         4.000e+00],
#        ...,
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 6.700e+02, 1.699e+03,
#         4.000e+00],
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 8.490e+02, 1.498e+03,
#         4.000e+00],
#        [0.000e+00, 1.000e+00, 0.000e+00, ..., 1.028e+03, 1.514e+03,
#         4.000e+00]])

# %%
x
# Out:
# array([[1.000e+00, 0.000e+00, 0.000e+00, ..., 1.720e+02, 9.200e+02,
#         0.000e+00],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 6.010e+02, 1.111e+03,
#         0.000e+00],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 3.140e+02, 1.671e+03,
#         0.000e+00],
#        ...,
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 5.610e+02, 1.110e+03,
#         1.100e+01],
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 5.610e+02, 1.657e+03,
#         1.100e+01],
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 6.810e+02, 3.310e+02,
#         1.100e+01]])

# %%
model=joblib.load("model.pkl")

# %%
x_train.shape
# Out:
# (7640, 26)

# %%
df.drop("Aggregate rating",axis=1)
# Out:
#                Restaurant Name Country Code              City  \
# 0             Le Petit Souffle          162       Makati City
# 1             Izakaya Kikufuji          162       Makati City
# 2       Heat - Edsa Shangri-La          162  Mandaluyong City
# 3                         Ooma          162  Mandaluyong City
# 4                  Sambo Kojin          162  Mandaluyong City
# ...                        ...          ...               ...
# 9546               Naml۱ Gurme          208         ��stanbul
# 9547              Ceviz A��ac۱          208         ��stanbul
# 9548                     Huqqa          208         ��stanbul
# 9549               A���k Kahve          208         ��stanbul
# 9550  Walter's Coffee Roastery          208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# ...

# %%
# Keep a copy of the original column list
feature_names = df.drop("Aggregate rating",axis=1).columns.to_list()          # X is your original DataFrame

# … later, after the model is trained
importances = model.feature_importances_
fi = (pd.DataFrame({'Feature': feature_names,
                    'Importance': importances})
      .sort_values('Importance', ascending=False))
print(fi.head(10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 6
#       4 # … later, after the model is trained
#       5 importances = model.feature_importances_
# ----> 6 fi = (pd.DataFrame({'Feature': feature_names,
#       7                     'Importance': importances})
#       8       .sort_values('Importance', ascending=False))
#       9 print(fi.head(10))
#
# File c:\Users\gwm93\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
# ...

# %%
"""
Random Forest Regressor — training, evaluation & feature‑importance extraction
This version plugs neatly into an existing notebook where you already have:
• X, y — your original DataFrame & target
• x_train, x_test, y_train, y_test — split (and possibly transformed) arrays
• evaluate_model(...) — helper that returns MAE, RMSE, R²

It **automatically figures out the right feature names** whether you:
  ▸ kept the DataFrame columns intact,
  ▸ used a fitted ColumnTransformer / Pipeline (variable: `preprocessor`), or
  ▸ manually fitted an OneHotEncoder (variable: `encoder`).

One code block, drop‑in ready.
"""

import pandas as pd
import numpy as np
import joblib
from sklearn.ensemble import RandomForestRegressor

# ---------------------------------------------------------------------------
# 1. Capture original DataFrame column names BEFORE any array conversion
# ---------------------------------------------------------------------------
try:
    original_feature_names = X.columns.to_list()          # X must exist in the workspace
except NameError:
    original_feature_names = None  # Fallback handled later

# ---------------------------------------------------------------------------
# 2. Define (or re‑define) the model dictionary
# ---------------------------------------------------------------------------
models = {
    "Random Forest Regressor": RandomForestRegressor(
        n_estimators=100,
        min_samples_split=2,
        max_features=5,
        max_depth=15,
        n_jobs=-1,
        random_state=42,   # reproducibility
    )
}

# ---------------------------------------------------------------------------
# 3. Training, evaluation, feature‑importance extraction, persistence
# ---------------------------------------------------------------------------
for name, model in models.items():
    # --- fit ---------------------------------------------------------------
    model.fit(x_train, y_train)

    # --- predict -----------------------------------------------------------
    y_train_pred = model.predict(x_train)
    y_test_pred  = model.predict(x_test)

    # --- metrics -----------------------------------------------------------
    train_mae, train_rmse, train_r2 = evaluate_model(y_train, y_train_pred)
    test_mae,  test_rmse,  test_r2  = evaluate_model(y_test,  y_test_pred)

    print(f"\n{name}")
    print("Model performance for Training set")
    print(f"- Root Mean Squared Error: {train_rmse:.4f}")
    print(f"- Mean Absolute Error:     {train_mae:.4f}")
    print(f"- R2 Score:                {train_r2:.4f}")
    print("----------------------------------")
    print("Model performance for Test set")
    print(f"- Root Mean Squared Error: {test_rmse:.4f}")
    print(f"- Mean Absolute Error:     {test_mae:.4f}")
    print(f"- R2 Score:                {test_r2:.4f}")
    print("=" * 35)

    # --- feature importance ----------------------------------------------
    importances = model.feature_importances_

    # Attempt to retrieve the correct feature names in this order:
    # 1. From a fitted ColumnTransformer / Pipeline called `preprocessor`
    # 2. From a fitted OneHotEncoder called `encoder`
    # 3. From the original DataFrame columns captured earlier
    # 4. Fallback to generic f0, f1, … labels
    feature_names = None
    for source in ("preprocessor", "encoder"):
        if feature_names is None and source in globals():
            obj = globals()[source]
            # Only if the object was fitted (has feature names)
            if hasattr(obj, "get_feature_names_out"):
                try:
                    feature_names = obj.get_feature_names_out()
                except Exception:
                    pass
    if feature_names is None and original_feature_names is not None:
        feature_names = original_feature_names
    if feature_names is None or len(feature_names) != len(importances):
        feature_names = [f"f{i}" for i in range(len(importances))]

    fi_df = (
        pd.DataFrame({"Feature": feature_names, "Importance": importances})
          .sort_values("Importance", ascending=False)
          .reset_index(drop=True)
    )

    # Display top‑10 for quick sanity check
    print("\nTop 10 important features:")
    print(fi_df.head(10).to_string(index=False))

    # --- persist model & importances -------------------------------------
    safe_name = name.replace(" ", "_").lower()
    joblib.dump(model,         f"{safe_name}_model.pkl")
    fi_df.to_csv(              f"{safe_name}_feature_importances.csv", index=False)

print("\nAll models trained and saved, along with their feature‑importance tables.")
# Out:
# Random Forest Regressor
# Model performance for Training set
# - Root Mean Squared Error: 0.1230
# - Mean Absolute Error:     0.0816
# - R2 Score:                0.9934
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.1664
# - Mean Absolute Error:     0.1164
# - R2 Score:                0.9878
# ...
#
# Top 10 important features:
#                          Feature  Importance
#    oh_encode__Rating color_White    0.311657
# oh_encode__Rating text_Not rated    0.256015
#                  standard__Votes    0.207627
#   oh_encode__Rating color_Orange    0.045809
# oh_encode__Rating text_Very Good    0.033927
#   oh_encode__Rating color_Yellow    0.026421
#    oh_encode__Rating color_Green    0.023714
#            standard__Price range    0.023162
# oh_encode__Rating text_Excellent    0.015372
#      oh_encode__Rating text_Good    0.010438
#
# All models trained and saved, along with their feature‑importance tables.
